# %%
import pandas as pd

# %%
matches = pd.read_csv('./IPL dataset/matches.csv')
deliveries = pd.read_csv('./IPL dataset/deliveries.csv')

# %%
deliveries.head(125)
# Out:
#      match_id  inning                 batting_team  \
# 0      335982       1        Kolkata Knight Riders
# 1      335982       1        Kolkata Knight Riders
# 2      335982       1        Kolkata Knight Riders
# 3      335982       1        Kolkata Knight Riders
# 4      335982       1        Kolkata Knight Riders
# ..        ...     ...                          ...
# 120    335982       1        Kolkata Knight Riders
# 121    335982       1        Kolkata Knight Riders
# 122    335982       1        Kolkata Knight Riders
# 123    335982       1        Kolkata Knight Riders
# 124    335982       2  Royal Challengers Bangalore
#
#                     bowling_team  over  ball       batter    bowler  \
# 0    Royal Challengers Bangalore     0     1   SC Ganguly   P Kumar
# 1    Royal Challengers Bangalore     0     2  BB McCullum   P Kumar
# 2    Royal Challengers Bangalore     0     3  BB McCullum   P Kumar
# 3    Royal Challengers Bangalore     0     4  BB McCullum   P Kumar
# ...

# %%
matches
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
matches_KKR = deliveries[(deliveries['batting_team'] == 'Kolkata Knight Riders') | (deliveries['bowling_team'] == 'Kolkata Knight Riders')]
matches_KKR
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
KKR_match1 = matches_KKR[matches_KKR['match_id'] == 335982]
KKR_match1
# Out:
#      match_id  inning                 batting_team  \
# 0      335982       1        Kolkata Knight Riders
# 1      335982       1        Kolkata Knight Riders
# 2      335982       1        Kolkata Knight Riders
# 3      335982       1        Kolkata Knight Riders
# 4      335982       1        Kolkata Knight Riders
# ..        ...     ...                          ...
# 220    335982       2  Royal Challengers Bangalore
# 221    335982       2  Royal Challengers Bangalore
# 222    335982       2  Royal Challengers Bangalore
# 223    335982       2  Royal Challengers Bangalore
# 224    335982       2  Royal Challengers Bangalore
#
#                     bowling_team  over  ball       batter     bowler  \
# 0    Royal Challengers Bangalore     0     1   SC Ganguly    P Kumar
# 1    Royal Challengers Bangalore     0     2  BB McCullum    P Kumar
# 2    Royal Challengers Bangalore     0     3  BB McCullum    P Kumar
# 3    Royal Challengers Bangalore     0     4  BB McCullum    P Kumar
# ...

# %%
KKR_match1_inning1 = KKR_match1[KKR_match1['batting_team'] == 'Kolkata Knight Riders']
KKR_match1_inning1
# Out:
#      match_id  inning           batting_team                 bowling_team  \
# 0      335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1      335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2      335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3      335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4      335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ..        ...     ...                    ...                          ...
# 119    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 120    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 121    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 122    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 123    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
#
#      over  ball       batter   bowler      non_striker  batsman_runs  \
# ...

# %%
KKR_match1_inning2 = KKR_match1[KKR_match1['batting_team'] == 'Royal Challengers Bangalore']
KKR_match1_inning2.reset_index(drop = True)
# Out:
#      match_id  inning                 batting_team           bowling_team  \
# 0      335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 1      335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 2      335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 3      335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 4      335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# ..        ...     ...                          ...                    ...
# 96     335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 97     335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 98     335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 99     335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 100    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
#
#      over  ball    batter     bowler non_striker  batsman_runs  extra_runs  \
# ...

# %%
team_names = matches['team1'].unique()
team_names
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
batsman_names = list(deliveries['batter'].unique())
bowler_names = list(deliveries['bowler'].unique())
#print(len(bowler_names))
#len(batsman_names)

all_players = batsman_names+bowler_names

for i in range(len(all_players)):
    if all_players[i] not in unique_players:
        unique_players.append(all_players[i])
print(unique_players)
print(len(unique_players))
# Out:
# ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'DJ Hussey', 'Mohammad Hafeez', 'R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis', 'CL White', 'MV Boucher', 'B Akhil', 'AA Noffke', 'P Kumar', 'Z Khan', 'SB Joshi', 'PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dhoni', 'SK Raina', 'JDP Oram', 'S Badrinath', 'K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvraj Singh', 'SM Katich', 'IK Pathan', 'T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'G Gambhir', 'V Sehwag', 'S Dhawan', 'L Ronchi', 'ST Jayasuriya', 'DJ Thornely', 'RV Uthappa', 'PR Shah', 'AM Nayar', 'SM Pollock', 'Harbhajan Singh', 'S Chanderpaul', 'LRPL Taylor', 'AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxman', 'A Symonds', 'RG Sharma', 'SB Styris', 'AS Yadav', 'SB Bangar', 'WPUJC Vaas', 'RP Singh', 'WP Saha', 'LR Shukla', 'DPMD Jayawardene', 'S Sohal', 'B Lee', 'PP Chawla', 'WA Mota', 'Kamran Akmal', 'Shahid Afridi', 'DJ Bravo', 'MA Khote', 'A Nehra', 'GC Smith', 'Pank
# ...

# %%
SC_ganguly_batting_stats = deliveries[deliveries['batter'] == 'SC Ganguly']
SC_ganguly_batting_stats
# Out:
#        match_id  inning           batting_team                 bowling_team  \
# 0        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 13       335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 14       335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 15       335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 18       335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...         ...     ...                    ...                          ...
# 74834    548375       2          Pune Warriors        Kolkata Knight Riders
# 74836    548375       2          Pune Warriors        Kolkata Knight Riders
# 74838    548375       2          Pune Warriors        Kolkata Knight Riders
# 74841    548375       2          Pune Warriors        Kolkata Knight Riders
# 74847    548375       2          Pune Warriors        Kolkata Knight Riders
#
# ...

# %%
SC_ganguly_matchIDs = SC_ganguly_batting_stats['match_id'].unique()
print(SC_ganguly_matchIDs)
print(len(SC_ganguly_matchIDs))
# Out:
# [335982 335986 335993 335997 336000 336003 336010 336014 336017 336021
#  336025 336027 336035 392184 392190 392197 392199 392203 392207 392219
#  392221 392228 392231 392233 419106 419109 419113 419118 419122 419127
#  419131 419135 419139 419144 419148 419153 419158 419161 501250 501259
#  501262 548308 548313 548319 548322 548327 548330 548333 548337 548341
#  548348 548351 548353 548358 548365 548375]
# 56

# %%
#for i in range(len(SC_ganguly_matchIDs)): 
SC_ganguly_batting_match_1 = SC_ganguly_batting_stats[SC_ganguly_batting_stats['match_id'] == SC_ganguly_matchIDs[1]]
total_runs = SC_ganguly_batting_match_1['batsman_runs'].sum()
print(total_runs)
SC_ganguly_batting_match_1
# Out:
# 14
#       match_id  inning           batting_team     bowling_team  over  ball  \
# 1069    335986       2  Kolkata Knight Riders  Deccan Chargers     2     2
# 1070    335986       2  Kolkata Knight Riders  Deccan Chargers     2     3
# 1077    335986       2  Kolkata Knight Riders  Deccan Chargers     3     4
# 1084    335986       2  Kolkata Knight Riders  Deccan Chargers     4     5
# 1085    335986       2  Kolkata Knight Riders  Deccan Chargers     4     6
# 1086    335986       2  Kolkata Knight Riders  Deccan Chargers     5     1
# 1091    335986       2  Kolkata Knight Riders  Deccan Chargers     5     6
# 1092    335986       2  Kolkata Knight Riders  Deccan Chargers     6     1
# 1093    335986       2  Kolkata Knight Riders  Deccan Chargers     6     2
# 1094    335986       2  Kolkata Knight Riders  Deccan Chargers     6     3
# 1095    335986       2  Kolkata Knight Riders  Deccan Chargers     6     4
# ...
